# %%
# !pip install pandas pyarrow
# !pip install geopandas
# !pip install contextily

import sys
import pandas as pd
import geopandas as gpd
import contextily as cx
import pyarrow as pa
import pyarrow.parquet as pq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 306.0 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 944.6 kB/s eta 0:00:00m eta 0:00:0136m0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 kB 928.5 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 983.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 704.5 kB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 329.3 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 1.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...

# %%
#df = pd.read_csv('/content/drive/MyDrive/BigData/stop_times.txt')
#df = pd.read_csv('stop_times.txt')
##shapes_df = pd.read_csv('shapes.txt')
#stops_df = pd.read_csv('stops.txt')
stop_times_df = pd.read_csv('stop_times.txt')
with open('stop_times.txt') as file:
    
    lines=file.readlines()
lines

print(lines)
"""
stop_times_df = pd.read_csv('stop_times.txt')



gdf = gpd.GeoDataFrame(stops_df, geometry=gpd.points_from_xy(stops_df['stop_lon'], stops_df['stop_lat']))  #stops_df['shape_pt_lon'], stops_df['shape_pt_lat']))

from pandas._libs.tslibs.fields import get_date_name_field


import shapely.affinity
from shapely.geometry import Point
import numpy as np

# BME I épület koordinátái 47.47256, 19.05965
Ipoint = (47.47256, 19.05965)
#ellipse = shapely.affinity.scale(circle, 20, 20)

gdf["distance"] = np.sqrt(
    (gdf["stop_lat"] - 47.47256)**2 + (gdf["stop_lon"] - 19.05965)**2
)

# Select rows where the distance is less than or equal to 800 meters
gdf = gdf.loc[gdf["distance"] <= 0.008]

##gdf = gdf.drop(gdf["location_type"])

print(gdf)
circle = Point(19.05965, 47.47256).buffer(100)


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(5,5))
sns.heatmap(gdf.corr(), annot=False, cmap=plt.cm.Blues)
plt.show()
#gdf = gdf[gdf.geometry.within(circle)]

#temp = gdf[gdf["stop_lat"] < 47.519839 & gdf["stop_lat"] > 47.520681 & gdf["stop_lon"] > 19.137211 & gdf["stop_lon"] < 19.148638 ]
"""

# %%
print("Hello")
# Out:
# Hello
